# %%
import csv
import random
import numpy as np 
import matplotlib.pyplot as plt
lst =[]
before=[]
after=[]
title=[]
i=0
while(i<5):
	n = random.randint(1,30)
	if(n in lst):
		continue
	lst.append(n)
	i+=1
with open('analyzation_details.csv',encoding="utf8") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
    	if(row[0].isdigit()):
	    	if(int(row[0]) in lst):
	    		before.append(int(row[2]))
	    		after.append(int(row[3]))
	    		title.append("Blog"+str(row[0]))
X_axis = np.arange(len(before))
plt.bar(X_axis-0.2,before,0.4,label = 'Before Summarization')
plt.bar(X_axis+0.2,after,0.4,label = 'After Summarization')
plt.xticks(X_axis, title,fontsize=11,fontname="Calibri")     #red and green
plt.yticks(fontsize=11,fontname="Calibri")
plt.xlabel("Blog Posts",fontsize=11,fontname="Calibri",labelpad=8)
plt.ylabel("Number of Lines of Text",fontsize=11,fontname="Calibri",labelpad=8)
plt.title("Lines of Text of a Blog Before and After Sumarization (Dynamic)",fontsize=11,fontname="Calibri",pad=15)
plt.legend(fontsize=7,borderpad=1.2,prop={'family':'Calibri', 'size':10})
plt.show()

# %%
lst =[1,2,3,4,5]
before=[]
after=[]
title=[]
with open('analyzation_details.csv',encoding="utf8") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
    	if(row[0].isdigit()):
	    	if(int(row[0]) in lst):
	    		before.append(int(row[2]))
	    		after.append(int(row[3]))
	    		title.append("Blog"+str(row[0]))
X_axis = np.arange(len(before))
plt.bar(X_axis-0.2,before,0.4,label = 'Before Summarization')
plt.bar(X_axis+0.2,after,0.4,label = 'After Summarization')
plt.xticks(X_axis, title,fontsize=11,fontname="Calibri")     #red and green
plt.yticks(fontsize=11,fontname="Calibri")
plt.xlabel("Blog Posts",fontsize=11,fontname="Calibri",labelpad=8)
plt.ylabel("Number of Lines of Text",fontsize=11,fontname="Calibri",labelpad=8)
plt.title("Lines of Text of a Blog Before and After Sumarization (Static)",fontsize=11,fontname="Calibri",pad=15)
plt.legend(fontsize=7,borderpad=1.2,prop={'family':'Calibri', 'size':10})
plt.show()

# %%
lst =[]
before=[]
after=[]
title=[]
i=0
while(i<5):
	n = random.randint(1,30)
	if(n in lst):
		continue
	lst.append(n)
	i+=1
with open('analyzation_details.csv',encoding="utf8") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
    	if(row[0].isdigit()):
	    	if(int(row[0]) in lst):
	    		before.append(int(row[4]))
	    		after.append(int(row[5]))
	    		title.append("Blog"+str(row[0]))
X_axis = np.arange(len(before))
plt.bar(X_axis-0.2,before,0.4,label = 'Before Summarization',color="saddlebrown")
plt.bar(X_axis+0.2,after,0.4,label = 'After Summarization',color="teal")
plt.xticks(X_axis, title,fontsize=11,fontname="Calibri")
plt.yticks(fontsize=11,fontname="Calibri")
plt.xlabel("Blog Posts",fontsize=11,fontname="Calibri",labelpad=8)
plt.ylabel("Number of Words of Text",fontsize=11,fontname="Calibri",labelpad=8)
plt.title("Words of Text of a Blog Before and After Sumarization (Dynamic)",fontsize=11,fontname="Calibri",pad=15)
plt.legend(fontsize=7,borderpad=1.2,prop={'family':'Calibri', 'size':10})
plt.show()

# %%
lst =[6,7,8,9,10]
before=[]
after=[]
title=[]
with open('analyzation_details.csv',encoding="utf8") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
    	if(row[0].isdigit()):
	    	if(int(row[0]) in lst):
	    		before.append(int(row[4]))
	    		after.append(int(row[5]))
	    		title.append("Blog"+str(row[0]))
X_axis = np.arange(len(before))
plt.bar(X_axis-0.2,before,0.4,label = 'Before Summarization',color="saddlebrown")
plt.bar(X_axis+0.2,after,0.4,label = 'After Summarization',color="teal")
plt.xticks(X_axis, title,fontsize=11,fontname="Calibri")
plt.yticks(fontsize=11,fontname="Calibri")
plt.xlabel("Blog Posts",fontsize=11,fontname="Calibri",labelpad=8)
plt.ylabel("Number of Words of Text",fontsize=11,fontname="Calibri",labelpad=8)
plt.title("Words of Text of a Blog Before and After Sumarization (Static)",fontsize=11,fontname="Calibri",pad=15)
plt.legend(fontsize=7,borderpad=1.2,prop={'family':'Calibri', 'size':10})
plt.show()

# %%
lst =[]
before=[]
after=[]
title=[]
i=0
while(i<5):
	n = random.randint(1,30)
	if(n in lst):
		continue
	lst.append(n)
	i+=1
with open('analyzation_details.csv',encoding="utf8") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
    	if(row[0].isdigit()):
	    	if(int(row[0]) in lst):
	    		before.append(int(row[6]))
	    		after.append(int(row[7]))
	    		title.append("Blog"+str(row[0]))
X_axis = np.arange(len(before))
plt.bar(X_axis-0.2,before,0.4,label = 'Before Summarization',color="slategrey")
plt.bar(X_axis+0.2,after,0.4,label = 'After Summarization',color="skyblue")
plt.xticks(X_axis, title,fontsize=11,fontname="Calibri")
plt.yticks(fontsize=11,fontname="Calibri")
plt.xlabel("Blog Posts",fontsize=11,fontname="Calibri",labelpad=8)
plt.ylabel("Time to Deluge the Content",fontsize=11,fontname="Calibri",labelpad=8)
plt.title("Time to Read Contents of a Blog Before and After Sumarization (Dynamic)",fontsize=11,fontname="Calibri",pad=15)
plt.legend(fontsize=7,borderpad=1.2,prop={'family':'Calibri', 'size':10})
plt.show()

# %%
lst =[11,12,13,14,15]
before=[]
after=[]
title=[]
with open('analyzation_details.csv',encoding="utf8") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
    	if(row[0].isdigit()):
	    	if(int(row[0]) in lst):
	    		before.append(int(row[6]))
	    		after.append(int(row[7]))
	    		title.append("Blog"+str(row[0]))
X_axis = np.arange(len(before))
plt.bar(X_axis-0.2,before,0.4,label = 'Before Summarization',color="slategrey")
plt.bar(X_axis+0.2,after,0.4,label = 'After Summarization',color="skyblue")
plt.xticks(X_axis, title,fontsize=11,fontname="Calibri")
plt.yticks(fontsize=11,fontname="Calibri")
plt.xlabel("Blog Posts",fontsize=11,fontname="Calibri",labelpad=8)
plt.ylabel("Time to Deluge the Content",fontsize=11,fontname="Calibri",labelpad=8)
plt.title("Time to Read Contents of a Blog Before and After Sumarization (Static)",fontsize=11,fontname="Calibri",pad=15)
plt.legend(fontsize=7,borderpad=1.2,prop={'family':'Calibri', 'size':10})
plt.show()

# %%
import matplotlib.pyplot as plt
x=["Week1","Week2","Week3","Week4","Week5","Week6","Week7","Week8"]
y1=[3,7,15,21,29,36,42,51]
y2=[7,13,20,26,32,39,46,58]
y3=[8,14,19,24,30,37,51,69]
y4=[5,10,16,21,27,34,48,57]
y5=[6,11,18,22,25,30,42,52]
y6=[2,5,11,18,21,26,38,49]
# plotting the line 1 points 
plt.plot(x, y1, label = "blog1")
plt.plot(x, y2, label = "blog6")
plt.plot(x, y3, label = "blog11")
plt.plot(x, y4, label = "blog16")
plt.plot(x, y5, label = "blog21")
plt.plot(x, y6, label = "blog26")
plt.xticks(x,fontsize=11,fontname="Calibri")
plt.xlabel('Weeks',fontsize=11,fontname="Calibri",labelpad=8)
plt.ylabel('Views of each blog in a Week',fontsize=11,fontname="Calibri",labelpad=8)
plt.title('Weekly analysis of each Blog views',fontsize=11,fontname="Calibri",pad=15)
plt.legend(fontsize=7,borderpad=1.2,prop={'family':'Calibri', 'size':10})
plt.show()

# %%
import matplotlib.pyplot as plt
x=["Before Summarization","After Summarization"]
y1=[0.0114219, 0.0078232]
y2=[0.0074384,0.0055133]
y3=[0.0058119,0.0029645]
y4=[0.004873,0.0028776]
y5=[0.0046398,0.0027229]
y6=[0.0027114,0.0025256]
# plotting the line 1 points 
plt.plot(x, y1, label = "30 blogs")
plt.plot(x, y2, label = "25 blogs")
plt.plot(x, y3, label = "20 blogs")
plt.plot(x, y4, label = "15 blogs")
plt.plot(x, y5, label = "10 blogs")
plt.plot(x, y6, label = "5 blogs")
plt.xticks(x,fontsize=11,fontname="Calibri")
plt.xlabel('Text Analysis Before and After Summarization of Contents',fontsize=11,fontname="Calibri",labelpad=8)
plt.ylabel('Time taken to Search the Contents',fontsize=11,fontname="Calibri",labelpad=8)
plt.title('Analysis of Search Duration',fontsize=11,fontname="Calibri",pad=15)
plt.legend(fontsize=7,borderpad=1.2,prop={'family':'Calibri', 'size':10})
plt.show()
